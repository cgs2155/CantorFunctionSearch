# %%
from fast_eig import *
from cantor_tools import *
import matplotlib.pyplot as plt

# %%
p=3
d=3
X = [p]*d#[5,3,3,2,2]
AFB = 2*np.pi/X[0]


memo = format_counter(CCAM_counter(X))
memo_fast = format_counter(pnary_CCAM_counter(p,d))


plt.plot(memo[0],memo[1],alpha=.5,color="red",label= "Generic")
plt.plot(memo_fast[0],memo_fast[1],alpha=.5,color="blue",label= "Pnary")



plt.legend()

# %%
f1 = cantors(5)

# %%
x = np.linspace(0,1,51)

p=3
d=10
memo_fast = format_counter(pnary_CCAM_counter(p,d))
normalized = (memo_fast[1] - memo_fast[1][0])/(2*memo_fast[1][-1])
plt.scatter(x,f1(x),label="Cantor's")
plt.plot(memo_fast[0], normalized,alpha=.5,color="blue",label= "CCAM Eigenvalues")



plt.legend()
